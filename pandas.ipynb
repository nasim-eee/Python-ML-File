# %% [markdown]
# <a href="https://colab.research.google.com/github/nasim-eee/Python-ML-File/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/Datasets/student_performance_data.csv'

columns = ['student_id', 'gender', 'study_hours_per_day', 'attendance_percentage',
           'assignment_score', 'midterm_score', 'final_exam_score', 'participation_score', 'internet_access',
           'extra_classes', 'parent_education','sleep_hours', 'overall_score', 'grade']

df = pd.read_csv(file_path, names=columns)   # raw CSV has no header
print('Loaded:', df.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loaded: (10001, 14)

# %%
df.head()
# Out:
#    student_id  gender  study_hours_per_day  attendance_percentage  \
# 0  student_id  gender  study_hours_per_day  attendance_percentage
# 1      100000    Male                 4.54                  69.98
# 2      100001  Female                 5.26                   84.8
# 3      100002    Male                 8.69                  73.76
# 4      100003    Male                 4.06                     45
#
#    assignment_score  midterm_score  final_exam_score  participation_score  \
# 0  assignment_score  midterm_score  final_exam_score  participation_score
# 1             36.47           70.7              53.1                17.96
# 2             34.25          27.92             87.17                11.29
# 3             72.29          70.92             99.61                 76.1
# 4             97.63          31.73             88.85                33.55
#
#    internet_access  extra_classes  parent_education  sleep_hours  \
# ...

# %%
df.describe()
# Out:
#        student_id gender study_hours_per_day attendance_percentage  \
# count       10001  10001               10001                 10001
# unique      10001      3                 902                  4873
# top        109999   Male                2.14                 86.71
# freq            1   5013                  23                     9
#
#        assignment_score midterm_score final_exam_score participation_score  \
# count             10001         10001            10001               10001
# unique             5313          5548             5323                6008
# top               79.41         31.83            31.72                72.8
# freq                  8             6                8                   6
#
#        internet_access extra_classes parent_education sleep_hours  \
# count            10001         10001            10001       10001
# unique               3             3                5         502
# ...

# %%
# Missing values and class balance — two checks you should always do
print('Missing per column:\n', df.isnull().sum(), sep='')
print('\nClass balance:\n', df['grade'].value_counts(normalize=True).round(3), sep='')
# Out:
# Missing per column:
# student_id               0
# gender                   0
# study_hours_per_day      0
# attendance_percentage    0
# assignment_score         0
# midterm_score            0
# final_exam_score         0
# participation_score      0
# internet_access          0
# extra_classes            0
# parent_education         0
# sleep_hours              0
# overall_score            0
# grade                    0
# dtype: int64
#
# Class balance:
# grade
# C        0.507
# B        0.270
# D        0.201
# A        0.015
# F        0.006
# grade    0.000
# Name: proportion, dtype: float64
